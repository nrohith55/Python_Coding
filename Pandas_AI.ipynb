# %%
import pandas as pd

# %%
df=pd.read_csv('data.tsv.txt',sep='\t')

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df.shape
# Out:
# (4622, 5)

# %%
print("The number of rows in the data set {}".format(df.shape[0]))
# Out:
# The number of rows in the data set 4622

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
#Which was the most ordered item?
most_ordered_item=df.groupby('item_name').sum()

# %%
most_ordered_item=most_ordered_item.sort_values(['quantity'],ascending=False)

# %%
most_ordered_item.head(1)
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %%
df.groupby(['item_name']).sum().sort_values(['quantity']).head(1)
# Out:
#                 order_id  quantity
# item_name
# Carnitas Salad      1500         1

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
#Which was the most ordered item in the choice description column

# %%
df.groupby(['choice_description']).sum().sort_values(['quantity'],ascending=False).head(1)
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %%
 #How many items were totally ordered?

# %%
total_orders= df['quantity'].sum()

# %%
total_orders
# Out:
# 4972

# %%
#How many different items were sold?

# %%
df['item_name'].value_counts()
# Out:
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Steak Bowl                               211
# Chips                                    211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chips and Fresh Tomato Salsa             110
# Chicken Salad Bowl                       110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %%
df['item_name'].value_counts().count()
# Out:
# 50

# %%
data=pd.read_csv("u.user",sep='|')

# %%
data
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
data.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
data.head(25)
# Out:
#     user_id  age gender     occupation zip_code
# 0         1   24      M     technician    85711
# 1         2   53      F          other    94043
# 2         3   23      M         writer    32067
# 3         4   24      M     technician    43537
# 4         5   33      F          other    15213
# 5         6   42      M      executive    98101
# 6         7   57      M  administrator    91344
# 7         8   36      M  administrator    05201
# 8         9   29      M        student    01002
# 9        10   53      M         lawyer    90703
# 10       11   39      F          other    30329
# 11       12   28      F          other    06405
# 12       13   47      M       educator    29206
# 13       14   45      M      scientist    55106
# 14       15   49      F       educator    97301
# 15       16   21      M  entertainment    10309
# 16       17   30      M     programmer    06355
# 17       18   35      F          other    37212
# 18       19   40      M      librarian    02138
# ...

# %%
data.shape
# Out:
# (943, 5)

# %%
data.shape[0]
# Out:
# 943

# %%
data.columns
# Out:
# Index(['user_id', 'age', 'gender', 'occupation', 'zip_code'], dtype='object')

# %%
data.dtypes
# Out:
# user_id        int64
# age            int64
# gender        object
# occupation    object
# zip_code      object
# dtype: object

# %%
data['occupation']
# Out:
# 0         technician
# 1              other
# 2             writer
# 3         technician
# 4              other
#            ...
# 938          student
# 939    administrator
# 940          student
# 941        librarian
# 942          student
# Name: occupation, Length: 943, dtype: object

# %%
data.occupation
# Out:
# 0         technician
# 1              other
# 2             writer
# 3         technician
# 4              other
#            ...
# 938          student
# 939    administrator
# 940          student
# 941        librarian
# 942          student
# Name: occupation, Length: 943, dtype: object

# %%
data[['gender','occupation','age']]
# Out:
#     gender     occupation  age
# 0        M     technician   24
# 1        F          other   53
# 2        M         writer   23
# 3        M     technician   24
# 4        F          other   33
# ..     ...            ...  ...
# 938      F        student   26
# 939      M  administrator   32
# 940      M        student   20
# 941      F      librarian   48
# 942      M        student   22
#
# [943 rows x 3 columns]

# %%
#How many different occupations is available in this dataset?

# %%
data['occupation'].value_counts().count()
# Out:
# 21

# %%
data.occupation.unique()
# Out:
# array(['technician', 'other', 'writer', 'executive', 'administrator',
#        'student', 'lawyer', 'educator', 'scientist', 'entertainment',
#        'programmer', 'librarian', 'homemaker', 'artist', 'engineer',
#        'marketing', 'none', 'healthcare', 'retired', 'salesman', 'doctor'],
#       dtype=object)

# %%
#What is the most frequent occupation?

# %%
data.occupation.value_counts().head(1)
# Out:
# student    196
# Name: occupation, dtype: int64

# %%
data.describe()
# Out:
#           user_id         age
# count  943.000000  943.000000
# mean   472.000000   34.051962
# std    272.364951   12.192740
# min      1.000000    7.000000
# 25%    236.500000   25.000000
# 50%    472.000000   31.000000
# 75%    707.500000   43.000000
# max    943.000000   73.000000

# %%
data.describe(include='all')
# Out:
#            user_id         age gender occupation zip_code
# count   943.000000  943.000000    943        943      943
# unique         NaN         NaN      2         21      795
# top            NaN         NaN      M    student    55414
# freq           NaN         NaN    670        196        9
# mean    472.000000   34.051962    NaN        NaN      NaN
# std     272.364951   12.192740    NaN        NaN      NaN
# min       1.000000    7.000000    NaN        NaN      NaN
# 25%     236.500000   25.000000    NaN        NaN      NaN
# 50%     472.000000   31.000000    NaN        NaN      NaN
# 75%     707.500000   43.000000    NaN        NaN      NaN
# max     943.000000   73.000000    NaN        NaN      NaN

# %%
#What is the average age of the users?

# %%
data.age.mean()
# Out:
# 34.05196182396607

# %%
#What are the age with lease occurences?

# %%
data.age.value_counts().tail()
# Out:
# 7     1
# 66    1
# 10    1
# 11    1
# 73    1
# Name: age, dtype: int64

# %%
#What are the age with most occurences?
data.age.value_counts().head()
# Out:
# 30    39
# 25    38
# 22    37
# 28    36
# 27    35
# Name: age, dtype: int64

# %%
import pandas as pd

# %%
euro_data = pd.read_csv('Euro_2012_stats_TEAM.csv')
euro_data
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
euro_data['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
#How many teams participated>''

# %%
euro_data['Team'].nunique()
# Out:
# 16

# %%
team_details_red_yellow_card = euro_data[["Team","Red Cards","Yellow Cards"]]
team_details_red_yellow_card
# Out:
#                    Team  Red Cards  Yellow Cards
# 0               Croatia          0             9
# 1        Czech Republic          0             7
# 2               Denmark          0             4
# 3               England          0             5
# 4                France          0             6
# 5               Germany          0             4
# 6                Greece          1             9
# 7                 Italy          0            16
# 8           Netherlands          0             5
# 9                Poland          1             7
# 10             Portugal          0            12
# 11  Republic of Ireland          1             6
# 12               Russia          0             6
# 13                Spain          0            11
# 14               Sweden          0             7
# 15              Ukraine          0             5

# %%
#Sort the teams by Red card and display in single table

# %%
team_details_red_yellow_card.sort_values(by=["Red Cards"],ascending=False)
# Out:
#                    Team  Red Cards  Yellow Cards
# 6                Greece          1             9
# 9                Poland          1             7
# 11  Republic of Ireland          1             6
# 0               Croatia          0             9
# 1        Czech Republic          0             7
# 2               Denmark          0             4
# 3               England          0             5
# 4                France          0             6
# 5               Germany          0             4
# 7                 Italy          0            16
# 8           Netherlands          0             5
# 10             Portugal          0            12
# 12               Russia          0             6
# 13                Spain          0            11
# 14               Sweden          0             7
# 15              Ukraine          0             5

# %%
# Calculate the mean of YellowCards per team

# %%
team_details_red_yellow_card["Yellow Cards"].mean()
# Out:
# 7.4375

# %%
#Filter the team that scored more than 8 goals.

# %%
euro_data[euro_data['Goals']>8]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %%
# [] - Filtering
# () - methods/function

# %%
import pandas as pd

# %%
df=pd.read_csv("drinks.csv")

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
df.country.nunique()
# Out:
# 193

# %%
df.country.value_counts()
# Out:
# Netherlands     1
# Sierra Leone    1
# Chile           1
# Austria         1
# Syria           1
#                ..
# Switzerland     1
# Hungary         1
# Romania         1
# Bolivia         1
# Serbia          1
# Name: country, Length: 193, dtype: int64

# %%
df.shape
# Out:
# (193, 6)

# %%
df.head(2)
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU

# %%
df.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
df.continent.unique()
# Out:
# array(['AS', 'EU', 'AF', nan, 'SA', 'OC'], dtype=object)

# %%
df.continent.nunique()
# Out:
# 5

# %%
#Which continent drinks more beer on average?

# %%
round(df.groupby('continent')['beer_servings'].mean())
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %%
#For each continent print the statistics report based on wine servings

# %%
df.groupby('continent')['wine_servings'].describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %%
user = pd.read_csv('u.user',sep = '|')
user
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
 #How many different occupation is available in the dataset?

# %%
user['occupation'].unique()
# Out:
# array(['technician', 'other', 'writer', 'executive', 'administrator',
#        'student', 'lawyer', 'educator', 'scientist', 'entertainment',
#        'programmer', 'librarian', 'homemaker', 'artist', 'engineer',
#        'marketing', 'none', 'healthcare', 'retired', 'salesman', 'doctor'],
#       dtype=object)

# %%
user['occupation'].value_counts()
# Out:
# student          196
# other            105
# educator          95
# administrator     79
# engineer          67
# programmer        66
# librarian         51
# writer            45
# executive         32
# scientist         31
# artist            28
# technician        27
# marketing         26
# entertainment     18
# healthcare        16
# retired           14
# lawyer            12
# salesman          12
# none               9
# homemaker          7
# doctor             7
# Name: occupation, dtype: int64

# %%
user['occupation'].nunique()
# Out:
# 21

# %%
#Discover the mean age of each occupation

# %%
user.groupby('occupation')['age'].mean().astype(int)
# Out:
# occupation
# administrator    38
# artist           31
# doctor           43
# educator         42
# engineer         36
# entertainment    29
# executive        38
# healthcare       41
# homemaker        32
# lawyer           36
# librarian        40
# marketing        37
# none             26
# other            34
# programmer       33
# retired          63
# salesman         35
# scientist        35
# student          22
# technician       33
# writer           36
# Name: age, dtype: int32

# %%
## 3. For each combination of occupation and gender, calculate the mean age.

# %%
user.groupby(['occupation','gender'])['age'].mean().astype(int)
# Out:
# occupation     gender
# administrator  F         40
#                M         37
# artist         F         30
#                M         32
# doctor         M         43
# educator       F         39
#                M         43
# engineer       F         29
#                M         36
# entertainment  F         31
#                M         29
# executive      F         44
#                M         38
# healthcare     F         39
#                M         45
# homemaker      F         34
#                M         23
# lawyer         F         39
#                M         36
# librarian      F         40
#                M         40
# marketing      F         37
#                M         37
# none           F         36
#                M         18
# other          F         35
#                M         34
# programmer     F         32
#                M         33
# retired        F         70
#                M         62
# salesman       F         27
# ...

# %%
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
df.beer_servings.isnull().sum()
# Out:
# 0

# %%
df.beer_servings.notnull().sum()
# Out:
# 193

# %%
sales_data_2017 = pd.read_csv("Sales Transactions-2017.csv")
sales_data_2018 = pd.read_csv("Sales Transactions-2018.csv")
sales_data_2019 = pd.read_csv("Sales Transactions-2019.csv")

# %%
sales_data_2017.head()
# Out:
#        Date Voucher               Party            Product  Qty      Rate  \
# 0  1/4/2017   Sal:1    SOLANKI PLASTICS      DONA-VAI-9100    2  1,690.00
# 1  1/4/2017   Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)    6  1,620.00
# 2  1/4/2017   Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE  500        23
# 3  1/4/2017   Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)    6  1,620.00
# 4  1/4/2017   Sal:2  SARNESWARA TRADERS      DONA-VAI-9100    5  1,690.00
#
#        Gross Disc Voucher Amount
# 0   3,380.00  NaN      13,100.00
# 1   9,720.00  NaN            NaN
# 2  11,500.00  NaN      30,990.00
# 3   9,720.00  NaN            NaN
# 4   8,450.00  NaN            NaN

# %%
sales_data_2018.head()
# Out:
#        Date  Voucher Party            Product       Qty Rate     Gross Disc  \
# 0  1/4/2018  Sal:146  TP13  SILVER POUCH 9*12        50   85  4,250.00  NaN
# 1  1/4/2018  Sal:146  TP13             RUBBER         5  290  1,450.00  NaN
# 2  1/4/2018  Sal:146  TP13   DURGA 10*12 Blue  1,600.00  5.5  8,800.00  NaN
# 3  1/4/2018  Sal:146  TP13   DURGA 13*16 BLUE       400   11  4,400.00  NaN
# 4  1/4/2018  Sal:146  TP13    10*12 SARAS-NAT       600  8.1  4,860.00  NaN
#
#   Voucher Amount
# 0      66,724.00
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
sales_data_2019.head()
# Out:
#        Date  Voucher            Party         Product  Qty      Rate  \
# 0  1/4/2019  Sal:687  BALAJI PLASTICS   DONA-VAI-9100    1  1,730.00
# 1  1/4/2019  Sal:687  BALAJI PLASTICS  SMART BOUL(48)    1  1,730.00
# 2  1/4/2019  Sal:688  BALAJI PLASTICS      Vishnu Ice  110      18.5
# 3                                28/3                    0         0
# 4  1/4/2019  Sal:689  BALAJI PLASTICS     100LEAF -SP    3       585
#
#       Gross Disc Voucher Amount
# 0  1,730.00  NaN       3,460.00
# 1  1,730.00  NaN            NaN
# 2  2,035.00  NaN       2,035.00
# 3
# 4  1,755.00  NaN       1,755.00

# %%
sales_data_2017.shape
# Out:
# (47290, 9)

# %%
sales_data_2018.shape
# Out:
# (44740, 9)

# %%
sales_data_2019.shape
# Out:
# (19176, 9)

# %%
sales_full_data = pd.concat([sales_data_2017,sales_data_2018,sales_data_2019],)
sales_full_data.head(50)
# Out:
#         Date   Voucher                Party              Product       Qty  \
# 0   1/4/2017     Sal:1     SOLANKI PLASTICS        DONA-VAI-9100         2
# 1   1/4/2017     Sal:1     SOLANKI PLASTICS      LITE FOAM(1200)         6
# 2   1/4/2017     Sal:2   SARNESWARA TRADERS    VISHNU CHOTA WINE       500
# 3   1/4/2017     Sal:2   SARNESWARA TRADERS      LITE FOAM(1200)         6
# 4   1/4/2017     Sal:2   SARNESWARA TRADERS        DONA-VAI-9100         5
# 5   1/4/2017     Sal:2   SARNESWARA TRADERS   CLASSIC ENJOY(750)         1
# 6   1/4/2017   Sal:898                 Lock         Vishnu 250ml       100
# 7   1/4/2017   Sal:898                 Lock      BLACK DOG-350ML       100
# 8                       khader vali late en
# 9                                       try
# 10  1/4/2017  Sal:2497  VAMSI KRISHNA FANCY          Loose Items         1
# 11       NaN       NaN               #NAME?                  NaN       NaN
# 12                              DUMMY ENTRY
# ...

# %%
sales_full_data = pd.concat([sales_data_2017,sales_data_2018,sales_data_2019])
sales_full_data.head(50)
# Out:
#         Date   Voucher                Party              Product       Qty  \
# 0   1/4/2017     Sal:1     SOLANKI PLASTICS        DONA-VAI-9100         2
# 1   1/4/2017     Sal:1     SOLANKI PLASTICS      LITE FOAM(1200)         6
# 2   1/4/2017     Sal:2   SARNESWARA TRADERS    VISHNU CHOTA WINE       500
# 3   1/4/2017     Sal:2   SARNESWARA TRADERS      LITE FOAM(1200)         6
# 4   1/4/2017     Sal:2   SARNESWARA TRADERS        DONA-VAI-9100         5
# 5   1/4/2017     Sal:2   SARNESWARA TRADERS   CLASSIC ENJOY(750)         1
# 6   1/4/2017   Sal:898                 Lock         Vishnu 250ml       100
# 7   1/4/2017   Sal:898                 Lock      BLACK DOG-350ML       100
# 8                       khader vali late en
# 9                                       try
# 10  1/4/2017  Sal:2497  VAMSI KRISHNA FANCY          Loose Items         1
# 11       NaN       NaN               #NAME?                  NaN       NaN
# 12                              DUMMY ENTRY
# ...

# %%
#df.set_index('month')
sales_full_data.set_index('Date',inplace=True)

# %%
sales_full_data
# Out:
#              Voucher               Party            Product           Qty  \
# Date
# 1/4/2017       Sal:1    SOLANKI PLASTICS      DONA-VAI-9100             2
# 1/4/2017       Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)             6
# 1/4/2017       Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE           500
# 1/4/2017       Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)             6
# 1/4/2017       Sal:2  SARNESWARA TRADERS      DONA-VAI-9100             5
# ...              ...                 ...                ...           ...
# 10/10/2019  Sal:4935           K.SRIHARI     13*16 WHITE RK           400
# NaN              NaN                 NaN                NaN           NaN
# NaN              NaN                 NaN                NaN           NaN
# NaN          Total                   NaN                NaN     99,284.90
# NaN          Total                   NaN                NaN  2,710,193.00
#
#                     Rate          Gross        Disc Voucher Amount
# Date
# ...

# %%
sales_data_2017.append([sales_data_2018,sales_data_2019])
# Out:
#              Date   Voucher               Party            Product  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...       ...                 ...                ...
# 19171  10/10/2019  Sal:4935           K.SRIHARI     13*16 WHITE RK
# 19172         NaN       NaN                 NaN                NaN
# 19173         NaN       NaN                 NaN                NaN
# 19174         NaN   Total                   NaN                NaN
# 19175         NaN   Total                   NaN                NaN
#
#                 Qty          Rate          Gross        Disc Voucher Amount
# 0                 2      1,690.00       3,380.00         NaN      13,100.00
# ...

# %%
import pandas as pd

# %%
drinks_data = pd.read_csv('drinks.csv')
drinks_data.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
del drinks_data['country']

# %%
drinks_data
# Out:
#      beer_servings  spirit_servings  wine_servings  \
# 0                0                0              0
# 1               89              132             54
# 2               25                0             14
# 3              245              138            312
# 4              217               57             45
# ..             ...              ...            ...
# 188            333              100              3
# 189            111                2              1
# 190              6                0              0
# 191             32               19              4
# 192             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# 3                            12.4        EU
# 4                             5.9        AF
# ..                            ...       ...
# ...

# %%
drinks_data.head()
# Out:
#    beer_servings  spirit_servings  wine_servings  \
# 0              0                0              0
# 1             89              132             54
# 2             25                0             14
# 3            245              138            312
# 4            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drinks_data.drop('beer_servings',axis=1,inplace=True)

# %%
drinks_data
# Out:
#      spirit_servings  wine_servings  total_litres_of_pure_alcohol continent
# 0                  0              0                           0.0        AS
# 1                132             54                           4.9        EU
# 2                  0             14                           0.7        AF
# 3                138            312                          12.4        EU
# 4                 57             45                           5.9        AF
# ..               ...            ...                           ...       ...
# 188              100              3                           7.7        SA
# 189                2              1                           2.0        AS
# 190                0              0                           0.1        AS
# 191               19              4                           2.5        AF
# 192               18              4                           4.7        AF
#
# [193 rows x 4 columns]

# %%
#Remove spirit_Servings and total_litres_of_pure_alcohol

# %%
drinks_data
# Out:
#      spirit_servings  wine_servings  total_litres_of_pure_alcohol continent
# 0                  0              0                           0.0        AS
# 1                132             54                           4.9        EU
# 2                  0             14                           0.7        AF
# 3                138            312                          12.4        EU
# 4                 57             45                           5.9        AF
# ..               ...            ...                           ...       ...
# 188              100              3                           7.7        SA
# 189                2              1                           2.0        AS
# 190                0              0                           0.1        AS
# 191               19              4                           2.5        AF
# 192               18              4                           4.7        AF
#
# [193 rows x 4 columns]

# %%
drinks_data.drop(['spirit_servings','wine_servings'],axis=1,inplace=True)

# %%
drinks_data
# Out:
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# 3                            12.4        EU
# 4                             5.9        AF
# ..                            ...       ...
# 188                           7.7        SA
# 189                           2.0        AS
# 190                           0.1        AS
# 191                           2.5        AF
# 192                           4.7        AF
#
# [193 rows x 2 columns]

# %%
insurance_data = pd.read_csv('insurance.csv')
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
insurance_data.describe(include = 'all' )
# Out:
#                 age   sex          bmi     children smoker     region  \
# count   1338.000000  1338  1338.000000  1338.000000   1338       1338
# unique          NaN     2          NaN          NaN      2          4
# top             NaN  male          NaN          NaN     no  southeast
# freq            NaN   676          NaN          NaN   1064        364
# mean      39.207025   NaN    30.663397     1.094918    NaN        NaN
# std       14.049960   NaN     6.098187     1.205493    NaN        NaN
# min       18.000000   NaN    15.960000     0.000000    NaN        NaN
# 25%       27.000000   NaN    26.296250     0.000000    NaN        NaN
# 50%       39.000000   NaN    30.400000     1.000000    NaN        NaN
# 75%       51.000000   NaN    34.693750     2.000000    NaN        NaN
# max       64.000000   NaN    53.130000     5.000000    NaN        NaN
#
#              charges
# count    1338.000000
# unique           NaN
# top              NaN
# freq             NaN
# ...

# %%
insurance_data.shape
# Out:
# (1338, 7)

# %%
insurance_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
insurance_data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
#Get the Region-wise average insurance charges.

# %%
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
insurance_data.groupby('region')['charges'].mean().astype(int)
# Out:
# region
# northeast    13406
# northwest    12417
# southeast    14735
# southwest    12346
# Name: charges, dtype: int32

# %%
#Get the Region and sex wise average insurance charges

# %%
insurance_data.groupby(['region','sex'])['charges'].mean().astype(int)
# Out:
# region     sex
# northeast  female    12953
#            male      13854
# northwest  female    12479
#            male      12354
# southeast  female    13499
#            male      15879
# southwest  female    11274
#            male      13412
# Name: charges, dtype: int32

# %%
drinks_data = pd.read_csv('drinks.csv')
drinks_data.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
for country in drinks_data:
    print(country)
# Out:
# country
# beer_servings
# spirit_servings
# wine_servings
# total_litres_of_pure_alcohol
# continent

# %%
drinks_data.query('continent == "AS"')
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 12                Bahrain             42               63              7
# 13             Bangladesh              0                0              0
# 19                 Bhutan             23                0              0
# 24                 Brunei             31                2              1
# 30               Cambodia             57               65              1
# 36                  China             79              192              8
# 46            North Korea              0                0              0
# 77                  India              9              114              0
# 78              Indonesia              5                1              0
# 79                   Iran              0                0              0
# 80                   Iraq              9                3              0
# ...

# %%
insurance_data = pd.read_csv('insurance.csv')
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
insurance_data.query('smoker == "yes" and sex == "female"')
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 23     34  female  31.920         1    yes  northeast  37701.87680
# 58     53  female  22.880         1    yes  southeast  23244.79020
# 64     20  female  22.420         0    yes  northwest  14711.74380
# ...   ...     ...     ...       ...    ...        ...          ...
# 1308   25  female  30.200         0    yes  southwest  33900.65300
# 1313   19  female  34.700         2    yes  southwest  36397.57600
# 1314   30  female  23.655         3    yes  northwest  18765.87545
# 1323   42  female  40.370         2    yes  southeast  43896.37630
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [115 rows x 7 columns]
